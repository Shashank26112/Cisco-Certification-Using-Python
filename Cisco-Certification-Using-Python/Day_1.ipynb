# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Bostonhousing.csv')

# %%
df.head(1)
# Out:
#       crim    zn  indus  chas    nox     rm   age   dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.09    1  296     15.3
#
#        b  lstat  medv
# 0  396.9   4.98  24.0

# %%
df.shape
# Out:
# (506, 14)

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
x = df.corr()

# %%
x
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
sns.heatmap(x, cmap = 'coolwarm', annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize = (20,20))
sns.heatmap(x, cmap = 'RdYlGn', annot = True)
plt.show()

# %%
df.head(1)
# Out:
#       crim    zn  indus  chas    nox     rm   age   dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.09    1  296     15.3
#
#        b  lstat  medv
# 0  396.9   4.98  24.0

# %%
x = df.drop('crim', axis = 1)
y = df['crim']
print(x.head(1),'\n\n\n', y.head(1))
# Out:
#      zn  indus  chas    nox     rm   age   dis  rad  tax  ptratio      b  \
# 0  18.0   2.31     0  0.538  6.575  65.2  4.09    1  296     15.3  396.9
#
#    lstat  medv
# 0   4.98  24.0
#
#
#  0    0.00632
# Name: crim, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x,train_y, test_y = train_test_split(x,y,test_size = 0.3, random_state = 1)

# %%
print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)
# Out:
# (354, 13) (354,) (152, 13) (152,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
model.score(test_x, test_y)
# Out:
# 0.3180335035566366

# %%
pred_y = model.predict(test_x)

# %%
from sklearn.metrics import mean_absolute_error as  mse

# %%
MSE = mse(pred_y, test_y)

# %%
MSE
# Out:
# 3.066995704499637

# %%
sns.scatterplot(x = pred_y,y =  test_y)
# Out:
# <AxesSubplot:ylabel='crim'>

# %%
# pip install statsmodels

# %%
df.head(1)
# Out:
#       crim    zn  indus  chas    nox     rm   age   dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.09    1  296     15.3
#
#        b  lstat  medv
# 0  396.9   4.98  24.0

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols('crim ~ zn+indus+chas+nox+rm+age+dis+rad+tax+ptratio+b+lstat+medv', data = df).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     31.47
# Date:                Tue, 17 Oct 2023   Prob (F-statistic):           1.57e-56
# Time:                        16:31:35   Log-Likelihood:                -1653.3
# No. Observations:                 506   AIC:                             3335.
# Df Residuals:                     492   BIC:                             3394.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     17.0332      7.235      2.354      0.019       2.818      31.248
# ...

# %%
model = LinearRegression()

# %%
model.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
model.score(test_x, test_y)
# Out:
# 0.3180335035566366

# %%
pred_y = model.predict(test_x)

# %%
print(model.coef_)
# Out:
# [ 5.70247393e-02 -6.74566219e-02 -9.89914112e-01 -1.32673385e+01
#  -4.72617694e-01  2.13259542e-03 -1.09132680e+00  6.01774464e-01
#  -4.43420525e-03 -2.58458171e-01 -1.34739553e-02  1.51489705e-01
#  -1.50089128e-01]

# %%
df_coef = pd.DataFrame({'Features':x.columns, 'CO_Efficients': model.coef_})

# %%
df_coef
# Out:
#    Features  CO_Efficients
# 0        zn       0.057025
# 1     indus      -0.067457
# 2      chas      -0.989914
# 3       nox     -13.267338
# 4        rm      -0.472618
# 5       age       0.002133
# 6       dis      -1.091327
# 7       rad       0.601774
# 8       tax      -0.004434
# 9   ptratio      -0.258458
# 10        b      -0.013474
# 11    lstat       0.151490
# 12     medv      -0.150089

# %%
df_coef = df_coef.sort_values(by = ['CO_Efficients'])
df_coef
# Out:
#    Features  CO_Efficients
# 3       nox     -13.267338
# 6       dis      -1.091327
# 2      chas      -0.989914
# 4        rm      -0.472618
# 9   ptratio      -0.258458
# 12     medv      -0.150089
# 1     indus      -0.067457
# 10        b      -0.013474
# 8       tax      -0.004434
# 5       age       0.002133
# 0        zn       0.057025
# 11    lstat       0.151490
# 7       rad       0.601774

# %%
df_coef.plot(x = 'Features', y = 'CO_Efficients', kind = 'bar', figsize = (15,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("R square value for regression test data is - :")
np.round(model.score(test_x, test_y)*100,2)
# Out:
# R square value for regression test data is - :
# 31.8

# %%
print("R square value for regression train data is - :")
np.round(model.score(train_x, train_y)*100,2)
# Out:
# R square value for regression train data is - :
# 50.58

# %%
from sklearn.metrics import mean_squared_error as  mse

# %%
print ("simple linear regression Mean square error (MSE) for TEST data is:")
np.round(mse(test_y,pred_y),2)
# Out:
# simple linear regression Mean square error (MSE) for TEST data is:
# 52.46

# %%
from  sklearn.metrics import mean_absolute_error as mae
print ("simple linear regression Mean absolute error (MAE) for TEST data is:")
np.round(mae(test_y,pred_y),2)
# Out:
# simple linear regression Mean absolute error (MAE) for TEST data is:
# 3.07

# %%
Final_df = pd.concat([test_x, test_y], axis = 1)

# %%
Final_df.head(1)
# Out:
#        zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio      b  \
# 307  33.0   2.18     0  0.472  6.849  70.3  3.1827    7  222     18.4  396.9
#
#      lstat  medv     crim
# 307   7.53  28.2  0.04932

# %%
Final_df['Predicted_values'] = np.round(pred_y,1)

# %%
Final_df.head(1)
# Out:
#        zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio      b  \
# 307  33.0   2.18     0  0.472  6.849  70.3  3.1827    7  222     18.4  396.9
#
#      lstat  medv     crim  Predicted_values
# 307   7.53  28.2  0.04932               4.2

# %%
Final_df['Predicted_Err'] = Final_df['crim']-Final_df['Predicted_values']

# %%
Final_df
# Out:
#        zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 307  33.0   2.18     0  0.472  6.849   70.3  3.1827    7  222     18.4
# 343  55.0   3.78     0  0.484  6.696   56.4  5.7321    5  370     17.6
# 47    0.0   6.91     0  0.448  6.030   85.5  5.6894    3  233     17.9
# 67   12.5   6.07     0  0.409  5.878   21.4  6.4980    4  345     18.9
# 362   0.0  18.10     0  0.770  5.362   96.2  2.1036   24  666     20.2
# ..    ...    ...   ...    ...    ...    ...     ...  ...  ...      ...
# 467   0.0  18.10     0  0.584  6.003   94.5  2.5403   24  666     20.2
# 95    0.0   2.89     0  0.445  6.625   57.8  3.4952    2  276     18.0
# 122   0.0  25.65     0  0.581  5.961   92.9  2.0869    2  188     19.1
# 260  20.0   3.97     0  0.647  7.203   81.8  2.1121    5  264     13.0
# 23    0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307     21.0
#
#           b  lstat  medv     crim  Predicted_values  Predicted_Err
# ...
